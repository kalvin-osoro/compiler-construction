# %% [markdown]
# <a href="https://colab.research.google.com/github/kalvin-osoro/compiler-construction/blob/main/Compiler_Construction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 115853 Joy Gichure
#
# 118915 Tertius Kabugi
#
# 122411 Gerry Masaka
#
# 123105 Collins Mwambi
#
# 122802 Kalvin Oanda

# %% [markdown]
# #Lab 1

# %% [markdown]
# **Flex (Fast LEXical analyzer generator)**
#
# Flex is a tool/computer program for generating lexical analyzers (scanners or lexers)
#  In stead of writing a scanner from scratch, you only need to identify the vocabulary of a certain language (e.g. Simple), write a specification of patterns using regular expressions (e.g. DIGIT [0-9]), and FLEX will construct a scanner for you.  FLEX reads a specification of a scanner either from an input file *.lex, or from standard input, and it generates as output a C source file lex.yy.c. Then, lex.yy.c is compiled and linked with the "-lfl" library to produce an executable a.out. Finally, a.out analyzes its input stream and transforms it into a sequence of tokens.
#
#  ![flex diag.png](data:image/png;base64,...)

# %%
# %%writefile flex.c
#
# %{
# int no_of_lines = 0;
# int no_of_chars = 0;
# %}
#
#
# %%
# \n	 ++no_of_lines;
# .	 ++no_of_chars;
# end	 return 0;
# %%
#
#
# int yywrap(){}
# int main(int argc, char **argv)
# {
#
# yylex();
# printf("number of lines = %d, number of chars = %d\n",
# 	no_of_lines, no_of_chars );
#
# return 0;
# }
# Out:
# Writing flex.c

# %% [markdown]
# **BISON**
#
# Bison is a  general-purpose parser generator that converts an annotated context-free grammar into a deterministic LR or generalized LR (GLR) parser employing LALR (1) parser tables. Parsers for LR(1) grammars are deterministic, meaning roughly that the next grammar rule to apply at any point in the input is uniquely determined by the preceding input and a fixed, finite portion (called a lookahead) of the remaining input. A context-free grammar can be ambiguous, meaning that there are multiple ways to apply the grammar rules to get the same inputs. The job of the Bison parser is to group tokens into groupings according to the grammar rules—for example, to build identifiers and operators into expressions.
#
# ![image.png](data:image/png;base64,...)
#
# Code snippet for simple error recovery
#
# line:
#
#   '\n'
#
# | exp '\n'   { printf ("\t%.10g\n", $1); }
#
# | error '\n' { yyerrok;                  }
#
# ;

# %% [markdown]
# **Lex**
#
#  Lex is a program that generates lexical analyzer. It is used together with YACC parser generator. A Lexical analyzer is a program that transforms an input stream into a stream of tokens. It reads the input stream and produces the source code as output through implementing the lexical analyzer in the C program.
#
#  ![lex.png](data:image/png;base64,...)

# %% [markdown]
# [Lex Code Snipet](https://drive.google.com/file/d/1-FesF2YLUKd0dcqb9cFgue_mmk3Q97rl/view?usp=sharing)

# %% [markdown]
# **Yacc** stands for Yet Another Compiler Compiler. It is a program designed to compile LALR grammar. YACC provides a tool to produce a parser for a given grammar. It is used to produce the source code of the synctactic analyzer of the language produced by the LALR grammar. The input of YACC is the rule or grammar and the output is a C program.
#
# [Yacc Code Snippet](https://drive.google.com/file/d/1iXoQYlyFZ01xpEM7iofAKV5BgoKiWady/view?usp=sharing)
#
#
# ![yacc.png](data:image/png;base64,...)

# %% [markdown]
# References
#
#
#
# <div class="csl-entry"><i>FLEX Tutorial</i>. (n.d.). Retrieved September 20, 2022, from http://alumni.cs.ucr.edu/~lgao/teaching/flex.html</div>
#
#
# <div class="csl-entry"><i>Flex (Fast Lexical Analyzer Generator ) - GeeksforGeeks</i>. (n.d.). Retrieved September 20, 2022, from https://www.geeksforgeeks.org/flex-fast-lexical-analyzer-generator/</div>
#
#
#
#  <div class="csl-entry"><i>Introduction to YACC - GeeksforGeeks</i>. (n.d.). Retrieved September 20, 2022, from https://www.geeksforgeeks.org/introduction-to-yacc/</div>
#
#
#
#   <div class="csl-entry"><i>YACC - javatpoint</i>. (n.d.). Retrieved September 20, 2022, from https://www.javatpoint.com/yacc</div>
#
#
#   <div class="csl-entry"><i>Bison 3.8.1</i>. (n.d.). Retrieved September 20, 2022, from https://www.gnu.org/software/bison/manual/bison.html</div>
#
#
#
#   <div class="csl-entry"><i>LEX - javatpoint</i>. (n.d.). Retrieved September 20, 2022, from https://www.javatpoint.com/lex</div>
#
#   <div class="csl-entry"><i>Simple Error Recovery (Bison 3.8.1)</i>. (n.d.). Retrieved September 20, 2022, from https://www.gnu.org/software/bison/manual/html_node/Simple-Error-Recovery.html</div>

# %% [markdown]
# #Lab 2

# %% [markdown]
# **NFA-DFA**
# ![WhatsApp Image 2022-09-20 at 22.48.57.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2022-09-20 at 22.54.33.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# **How to use Flex when building a simple Lexical Analyzer**
#
# **Step 1:** An input file describes the lexical analyzer to be generated named lex.l is written in lex language. The lex compiler transforms lex.l to C program, in a file that is always named lex.yy.c.
#
# **Step 2:** The C compiler compile lex.yy.c file into an executable file called a.out.
#
# **Step 3:** The output file a.out take a stream of input characters and produce a stream of tokens.
#
# **Program Structure: **
#
# In the input file, there are 3 sections:
#
# **1. Definition Section:**  The definition section contains the declaration of variables, regular definitions, manifest constants. In the definition section, text is enclosed in “**%{ %}**” brackets. Anything written in this brackets is copied directly to the file** lex.yy.c**
#
# Syntax:
#
# %{
#
#    // Definitions
#
# %}
#
#
# **2. Rules Section:** The rules section contains a series of rules in the form: pattern action and pattern must be unintended and action begin on the same line in {} brackets. The rule section is enclosed in “**%% %%**”.
#
# Syntax:
#
# %%
#
# pattern  action
#
# %%
#
# **3. User Code Section:** This section contains C statements and additional functions. We can also compile these functions separately and load with the lexical analyzer.
#
# Basic Program Structure:
#
# %{
#
# // Definitions
#
# %}
#
# %%
#
# Rules
#
# %%
#
# <!-- **How to run the program: **
#
# To run the program, it should be first saved with the extension .l or .lex. Run the below commands on terminal in order to run the program file.
#
# **Step 1:** lex filename.l or lex filename.lex depending on the extension file is saved with
#
# **Step 2:** gcc lex.yy.c
#
# **Step 3:** ./a.out
#
# **Step 4:** Provide the input to program in case it is required -->
#
# **Steps to use Bison:**
#
# 1. Write a lexical analyzer to process input and pass tokens to the parser (calc.lex).
#
# 2. Write the grammar specification for bison (calc.y), including grammar rules, yyparse() and yyerror().
#
# 3. Run Bison on the grammar to produce the parser. (Makefile)
#
# 4. Compile the code output by Bison, as well as any other source files.
#
# 5. Link the object files to produce the finished product.

# %% [markdown]
# **References**
#
# <div class="csl-entry"><i>Bison - Examples</i>. (n.d.). Retrieved September 20, 2022, from http://web.mit.edu/gnu/doc/html/bison_5.html</div>

# %% [markdown]
# #Lab 3
#
# Done in lab 1 above

# %% [markdown]
# #Lab 4
# **Predictive Parsing**
#
# A type of recursive descent parsing that does not require backtracking and can predict which products to use to replace the input string.
# To do so the grammar must be transformed in two ways; eliminate left recursion and perform left factoring.
#
# example
#
# Grammer;
#
# E → TE′
#
# E′ → +TE′|ε
#
# T′ → FT′
#
# T′ → FT′|ε
#
# F → (E)|id
#
# FIRST(E) = FIRST(T) = FIRST(F) = {(, id}
#
# FIRST (E′) = {+, ε}
#
# FIRST (T′) = {*, ε}
#
# FOLLOW (E) = FOLLOW(E′) = {), $}
#
# FOLLOW (T) = FOLLOW(T′) = {+, ), $}
#
# FOLLOW (F) = {+,*,),$}
#
#     NT Id	              +          	*           	(             )       	$
#
#     E → TE′	                                     E → TE′
#
#
#                     	E′ → +TE′	                                 E′ → ε	T′ → ε
#
#
#     T → FT′                                    	 T → FT′
#
#
# 	                  T′ → ε	T′ →* FT′                         	T′ → ε	T′ → ε
#
# 	  F → id	                                                         	 F → (E)
#
#   ![image.png](data:image/png;base64,...)
#
# An LL(1) parser is a top-down parser that employs a one-token lookahead.
# The first L denotes that the input is read left to right.
# The second L indicates that it generates a left-to-right derivation.
# And the 1 indicates that it only uses one lookahead token.
#
# The parser needs first and follow sets in order to correctly apply the required production rule at the proper position. FIRST and FOLLOW allow us to choose which production to apply, based on the next input symbol.
#
#  FIRST (α), where α is any string of grammar symbols, to be the set
# of terminals that begin strings derived from α.
#
# FOLLOW(A), for nonterminal A, to be the set of terminals α that can
# appear immediately to the right of A in some sentential form.

# %% [markdown]
# 3. Yes
#
#  **stacking**.  Both the stack and the input contains an end symbol $ to denote that the stack is empty and the input is consumed. The parser refers to the parsing table to take any decision on the input and stack element combination.
#
# **Error recovery**
#
#  Error conditions:
# • Terminal on top of the stack does not match the next input symbol
# • Nonterminal 𝐴 is on top of the stack, 𝑎 is the next input symbol, and 𝑀[𝐴, 𝑎]
# is error.
# Choice: Print an error message, try to recover from the error, and continue with
# compilation.
#
# Panic mode – skip over symbols until a token in a set of synchronizing
# (synch) tokens appears

# %% [markdown]
# **References**
#
# <div class="csl-entry"><i>LL(1) parsers</i>. (n.d.). Retrieved October 18, 2022, from http://www.cs.ecu.edu/karl/5220/spr16/Notes/Top-down/LL1.html</div>
#
#
#
# <div class="csl-entry"><i>Construct a Predictive Parsing table for the following grammar &#38; also check whether string id + id * id is accepted or not.</i> (n.d.). Retrieved October 18, 2022, from https://www.tutorialspoint.com/construct-a-predictive-parsing-table-for-the-following-grammar-and-also-check-whether-string-id-plus-id-id-is-accepted-or-not#</div>
#
#
# <div class="csl-entry"><i>CS 335: Top-down Parsing
# </i>. (n.d.). Retrieved October 18, 2022, from https://www.cse.iitk.ac.in/users/swarnendu/courses/spring2020-cs335/Top-down%20Parsing.pdf </div>
